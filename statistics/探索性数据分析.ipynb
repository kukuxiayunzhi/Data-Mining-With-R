# %% [markdown]
# ## 探索性数据分析

# %% [markdown]
# ### 常用分布的概率函数图

# %%
#二项分布
n<-20
p<-0.2
k<-seq(0,n)
plot(k,dbinom(k,n,p),type='h',main='Binomial distribution,n=20,p=0.2',xlab = 'k',col = 'red')
# Out:
# Plot with title "Binomial distribution,n=20,p=0.2"

# %%
#泊松分布
lambda<-4.0
k<-seq(0,20)
plot(k,dpois(k,lambda = lambda),type = 'h',main = 'Poisson distribution,lambda=5.5',
     xlab = 'k',col = 'red')
# Out:
# Plot with title "Poisson distribution,lambda=5.5"

# %%
#几何分布
p<-0.5
k<-seq(0,10)
plot(k,dgeom(k,p),type = 'h',main = 'Geometric distribution,p=0.5',
     xlab = 'k',col = 'red')
# Out:
# Plot with title "Geometric distribution,p=0.5"

# %%
#超几何分布
N<-30
M<-10
n<-10
k<-seq(0,10)
plot(k,dhyper(k,N,M,n),type = 'h',main = "Hypergeometric distribution,N=30,M=10,n=10",xlab = 'k')
# Out:
# Plot with title "Hypergeometric distribution,N=30,M=10,n=10"

# %%
#负二项分布
n<-10
p<-0.5
k<-seq(0,40)
plot(k, dnbinom(k,n,p), type='h',
    main='Negative Binomial distribution,n=10, p=0.5',xlab='k',col='blue')
# Out:
# Plot with title "Negative Binomial distribution,n=10, p=0.5"

# %%
#正态分布
curve(dnorm(x,0,1),xlim = c(-5,5),ylim=c(0,.8),col='red',lwd=2,lty=3)
curve(dnorm(x,0,2),add = T,col='blue',lwd=2,lty=2)
curve(dnorm(x,0,1/2),add = T,lwd=2,lty=1)
title(main = "Gaussian distributions")
legend(par('usr')[2],par('usr')[4],xjust = 1,
      c('sigma=1','sigma=2','sigma=1/2'),
      lwd=c(2,2,2),
      lty=c(3,2,1),
      col=c('red','blue',par("fg")))
# Out:
# Plot with title "Gaussian distributions"

# %%
#t分布
curve(dt(x,1),xlim = c(-3,3),ylim=c(0,.4),
     col='red',lwd=3,lty=1)
curve(dt(x,2),add = T,col='green',lwd=3,lty=1)
curve(dt(x,10),add = T,col='orange',lwd=3,lty=1)
curve(dnorm(x),add = T,lwd=3,lty=1)
title(main = "Student T distributions")
legend(par('usr')[2],par('usr')[4],xjust = 1,
      c('df=1','df=2','df=10','Gaussian distribution'),
      lwd=3,
      lty=1,
      col=c('red','blue','green',par('fg')))
# Out:
# Plot with title "Student T distributions"

# %%
#卡方分布
curve(dchisq(x,1), xlim=c(0,10), ylim=c(0,.6), col='red', lwd=2)
curve(dchisq(x,2), add=T, col='green', lwd=2)
curve(dchisq(x,3), add=T, col='blue', lwd=2)
curve(dchisq(x,5), add=T, col='orange', lwd=2)
abline(h=0,lty=3)
abline(v=0,lty=3)
title(main='Chi square Distributions')
legend(par('usr')[2], par('usr')[4], xjust=1,
        c('df=1', 'df=2', 'df=3', 'df=5'),
        lwd=3, lty=1,
        col=c('red', 'green', 'blue', 'orange')
     )
# Out:
# Plot with title "Chi square Distributions"

# %%
#F分布
curve(df(x,1,1), xlim=c(0,2), ylim=c(0,.8), lty=1)
curve(df(x,3,1), add=T, lwd=2,lty=2)
curve(df(x,6,1), add=T, lwd=2, lty=3)
curve(df(x,3,3), add=T, col='red', lwd=3,lty=4)
curve(df(x,3,6), add=T, col='blue', lwd=3,lty=5)
title(main="Fisher's F")
legend(par('usr')[2], par('usr')[4], xjust=1,
    c('df=(1,1)', 'df=(3,1)', 'df=(6,1)',
    'df=(3,3)', 'df=(3,6)'),
    lwd=c(1,2,2,3,3),
    lty=c(1,2,3,4,5),
    col=c(par("fg"), par("fg"), par("fg"), 'red', 'blue'))
# Out:
# Plot with title "Fisher's F"

# %%
#对数正态分布
curve(dlnorm(x), xlim=c(-.2,5), ylim=c(0,1.0), lwd=2)
curve(dlnorm(x,0,3/2), add=T, col='blue', lwd=2, lty=2)
curve(dlnorm(x,0,1/2), add=T, col='orange', lwd=2, lty=3)
title(main="Log normal distributions")
legend(par('usr')[2], par('usr')[4], xjust=1,
        c('sigma=1', 'sigma=2', 'sigma=1/2'),
        lwd=c(2,2,2),
        lty=c(1,2,3),
        col=c(par("fg"), 'blue', 'orange' ))
# Out:
# Plot with title "Log normal distributions"

# %%
#柯西分布
curve(dcauchy(x),xlim=c(-5,5), ylim=c(0,.5), lwd=3)
curve(dnorm(x), add=T, col='red', lty=2)
legend(par('usr')[2], par('usr')[4], xjust=1,
        c('Cauchy distribution', 'Gaussian distribution'),
        lwd=c(3,1),
        lty=c(1,2),
        col=c(par("fg"), 'red'))
# Out:
# plot without title

# %%
#威布尔分布
curve(dexp(x), xlim=c(0,3), ylim=c(0,2))
curve(dweibull(x,1), lty=3, lwd=3, add=T)
curve(dweibull(x,2), col='red', add=T)
curve(dweibull(x,.8), col='blue', add=T)
title(main="Weibull Probability Distribution Function")
legend(par('usr')[2], par('usr')[4], xjust=1,
        c('Exponential', 'Weibull, shape=1',
        'Weibull, shape=2', 'Weibull, shape=.8'),
        lwd=c(1,3,1,1),
        lty=c(1,3,1,1),
        col=c(par("fg"), par("fg"), 'red', 'blue'))
# Out:
# Plot with title "Weibull Probability Distribution Function"

# %%
#伽马分布
curve( dgamma(x,1,1), xlim=c(0,5), lwd=2, lty=1 )
curve( dgamma(x,2,1), add=T, col='red', lwd=2, lty=2 )
curve( dgamma(x,3,1), add=T, col='green', lwd=2, lty=3 )
curve( dgamma(x,4,1), add=T, col='blue', lwd=2, lty=4 )
curve( dgamma(x,5,1), add=T, col='orange', lwd=2, lty=5 )
title(main="Gamma distributions")
legend(par('usr')[2], par('usr')[4], xjust=1,
        c('k=1 (Exponential distribution)',
        'k=2', 'k=3', 'k=4', 'k=5'),
        lwd=c(2,2,2,2,2),
        lty=c(1,2,3,4,5),
        col=c(par('fg'), 'red', 'green', 'blue', 'orange'))
# Out:
# Plot with title "Gamma distributions"

# %%
#贝塔分布
curve( dbeta(x,1,1), xlim=c(0,1), ylim=c(0,4) )
curve( dbeta(x,3,1), add=T, col='green' )
curve( dbeta(x,3,2), add=T, lty=2, lwd=2 )
curve( dbeta(x,4,2), add=T, lty=2, lwd=2, col='blue' )
curve( dbeta(x,2,3), add=T, lty=3, lwd=3, col='red' )
curve( dbeta(x,4,3), add=T, lty=3, lwd=3, col='orange' )
title(main="Beta distributions")
legend(par('usr')[1], par('usr')[4], xjust=0,
        c('(1,1)', '(3,1)', '(3,2)',
        '(4,2)', '(2,3)', '(4,3)' ),
        lwd=c(1,1, 2,2, 3,3),
        lty=c(1,1, 2,2, 3,3),
        col=c(par('fg'), 'green', par('fg'),
        'blue', 'red', 'orange' ))
# Out:
# Plot with title "Beta distributions"

# %% [markdown]
# ### 直方图与密度函数的估计

# %% [markdown]
# ``` R
# hist(x, breaks = "Sturges", freq = NULL,
#     probability = !freq,
#     col = NULL,
#     main = paste("Histogram of" , xname),
#     xlim = range(breaks), ylim = NULL,
#     xlab = xname, ylab,
#     axes = TRUE, nclass = NULL)
# ```

# %% [markdown]
# - 样本的直方图粗略地描述了样本的分布，可以用函数density得到样本的核函数估计值，并用lines()得到密度估计的曲线。
# ``` R
# density(x, bw = "nrd0",
#         kernel = c("gaussian", "epanechnikov", "rectangular",
#         "triangular", "biweight", "cosine", "optcosine"),
#         n = 512, from, to)
# ```

# %%
#binom(10,0.9) N=100000
N <- 100000
n <- 100
p <- .9
x <- rbinom(N,n,p)
hist(x,
    xlim=c(min(x),max(x)), probability=T,
    nclass=max(x)-min(x)+1, col='lightblue',
    main='Binomial distribution, n=100, p=.9')
lines(density(x, kernel = "gaussian", bw=1),col='red', lwd=3)
# Out:
# Plot with title "Binomial distribution, n=100, p=.9"

# %%
N <- 100000
x <- rnbinom(N, 10, .25)
hist(x,
    xlim=c(min(x),max(x)), probability=T,
    nclass=max(x)-min(x)+1, col='lightblue',
    main='Negative binomial distribution, n=10, p=.25')
lines(density(x,bw=1), col='red', lwd=3)
# Out:
# Plot with title "Negative binomial distribution, n=10, p=.25"

# %% [markdown]
# ### 单组数据的描述性统计分析

# %%
#直方图
library(DAAG)
data(possum)
fpossum <- possum[possum$sex=="f",]
par(mfrow = c(1,2))
attach(fpossum)
hist(totlngth,breaks = 72.5+(0:5)*5,
    ylim=c(0,22),xlab="total length",
    main="A:Breaks at 72.5,77.5...")
hist(totlngth,breaks = 75+(0:5)*5,
    ylim=c(0,22),xlab="total length",
    main="B:Breaks at 75,80...")
# Out:
# Loading required package: lattice
# Plot with title "B:Breaks at 75,80..."

# %%
#茎叶图
stem(fpossum$totlngth)
# Out:
#   The decimal point is at the |
#
#   74 | 0
#   76 |
#   78 |
#   80 | 05
#   82 | 0500
#   84 | 05005
#   86 | 05505
#   88 | 0005500005555
#   90 | 5550055
#   92 | 000
#   94 | 05
#   96 | 5

# %%
#盒形图
#boxplot(formula, data = NULL, ..., subset, na.action = NULL)
boxplot(fpossum$totlngth)
# Out:
# plot without title

# %% [markdown]
# ### 正态性检验

# %%
#使用QQ图
qqnorm(fpossum$totlngth,
      main="Normality Check via QQ Plot")
qqline(fpossum$totlngth,col='red')
# Out:
# Plot with title "Normality Check via QQ Plot"

# %%
#与正态密度函数比较
dens <- density(totlngth)
xlim <- range(dens$x)
ylim <- range(dens$y)
par(mfrow = c(1,2))
hist(totlngth,breaks = 72.5+(0:5)*5,
    xlim=xlim,ylim=ylim,
    probability=T,xlab="total length",
    main="A:Breaks at 72.5,77.5...")
lines(dens,col=par('fg'),lty=2)
m <- mean(totlngth)
s <- sd(totlngth)
curve(dnorm(x,m,s),col='red',add = T)
hist(totlngth,breaks = 75+(0:5)*5,
    xlim=xlim,ylim=ylim,
    probability=T,xlab="total length",
    main="B:Breaks at 75,80...")
lines(dens,col = par('fg'),lty=2)
m<-mean(totlngth)
s<-sd(totlngth)
curve(dnorm(x,m,s),col='red',add = T)
# Out:
# Plot with title "B:Breaks at 75,80..."

# %%
#使用经验分布函数
x <- sort(totlngth)
n <- length(x)
y <- (1:n)/n
m <- mean(totlngth)
s <- sd(totlngth)
plot(x,y,type = 's',main = "empirical cdf of ")
curve(pnorm(x,m,s),col='red',lwd=2,add = T)
# Out:
# Plot with title "empirical cdf of "

# %%
#总体描述
summary(fpossum$totlngth)
mean(fpossum$totlngth)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   75.00   85.25   88.50   87.91   90.50   96.50
# [1] 87.90698

# %% [markdown]
# ### 单组数据的描述性统计

# %%
#五数
fivenum(fpossum$totlngth)
# Out:
# [1] 75.00 85.25 88.50 90.50 96.50

# %%
#分位数
quantile(fpossum$totlngth)
quantile(fpossum$totlngth,probs = c(0.25,0.5,0.75))
# Out:
#    0%   25%   50%   75%  100%
# 75.00 85.25 88.50 90.50 96.50
#   25%   50%   75%
# 85.25 88.50 90.50

# %%
#中位数
median(fpossum$totlngth)
#最值
max(fpossum$totlngth)
min(fpossum$totlngth)
# Out:
# [1] 88.5
# [1] 96.5
# [1] 75

# %% [markdown]
# **Tips**
# - 标准差函数sd的定义:
#     $$s d(x)=\sqrt{\frac{\sum_{i=1}^{n}\left(x_{i}-\bar{x}\right)}{n-1}}$$
# - mad 在R中的定义:
#     $$
#     1.4826 * \mathrm{median}(\mathrm{abs}(\mathrm{x}-\mathrm{median}    (\mathrm{x})))
# $$

# %%
#绝对离差函数
mad(fpossum$totlngth)
1.4826*median(abs(fpossum$totlngth-median(fpossum$totlngth)))
# Out:
# [1] 3.7065
# [1] 3.7065

# %%
1/qnorm(3/4)
# Out:
# [1] 1.482602

# %% [markdown]
# ### 样本偏度系数和峰度系数
# - 偏度系数:
# $$
# \beta_{1}=\frac{E(X-E(X))^{3}}{\left[E\left(X-E(X)^{2}\right]^{3 / 2}\right.}=\frac{\nu_{3}}{\left(\nu_{2}\right)^{3 / 2}}
# $$
# - 峰度系数:
# $$
# \beta_{2}=\frac{E(X-E(X))^{4}}{\left[E\left(X-E(X)^{2}\right]^{2}\right.}-3=\frac{\nu_{4}}{\left(\nu_{2}\right)^{2}}-3
# $$

# %%
library(fBasics)
# Out:
# Loading required package: timeDate
#
# Loading required package: timeSeries

# %%
####
skewness(fpossum$totlngth)
kurtosis(fpossum$totlngth)
basicStats(fpossum$totlngth)
# Out:
# [1] -0.54838
# attr(,"method")
# [1] "moment"
# [1] 0.6170082
# attr(,"method")
# [1] "excess"
#             X..fpossum.totlngth
# nobs          43.000000
# NAs            0.000000
# Minimum       75.000000
# Maximum       96.500000
# 1. Quartile   85.250000
# 3. Quartile   90.500000
# Mean          87.906977
# Median        88.500000
# Sum         3780.000000
# SE Mean        0.637786
# LCL Mean      86.619873
# UCL Mean      89.194081
# Variance      17.491141
# Stdev          4.182241
# Skewness      -0.548380
# Kurtosis       0.617008

# %% [markdown]
# ### 多组数据的描述性统计分析

# %%
library(DAAG)
data(cars)
summary(cars)
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
#二维数据 线性关系
plot(cars$dist~cars$speed,xlab = "Speed(mph)",ylab="Stopping distance (ft)")
lines(lowess(cars$speed,cars$dist),lwd=2)
#通过函数rug() 可以在坐标上标注数据的具体位置
rug(side=2,jitter(cars$dist,20))
rug(side=1,jitter(cars$speed,5))
# Out:
# plot without title

# %%
#加箱体图
op <- par( )
layout(matrix(c(2,1,0,3), 2, 2, byrow=T ), c(1,6), c(4,1))
par(mar=c(1,1,5,2))
plot(cars$dist ~ cars$speed,xlab='', ylab='', las = 1)
rug(side=1, jitter(cars$speed, 5))
rug(side=2, jitter(cars$dist, 20))
title(main = "cars data")
par(mar=c(1,2,5,1))
boxplot(cars$dist, axes=F)
title(ylab='Stopping distance (ft)', line=0)
par(mar=c(5,1,1,2))
boxplot(cars$speed, horizontal=T, axes=F)
title(xlab='Speed (mph)', line=1)
par(op)
# Out:
# Warning message in par(op):
# "无法设定图形参数"cin""
# Warning message in par(op):
# "无法设定图形参数"cra""
# Warning message in par(op):
# "无法设定图形参数"csi""
# Warning message in par(op):
# "无法设定图形参数"cxy""
# Warning message in par(op):
# "无法设定图形参数"din""
# Warning message in par(op):
# "无法设定图形参数"page""
# Plot with title "cars data"

# %%
#等高线图
library(MASS)
z <- kde2d(x,y)
contour(z,col = "red",drawlabels = FALSE,main = "Density estimation: contour plot")
# Out:
#  [1] 75.0 81.0 81.5 82.0 82.5 83.0 83.0 84.0 84.5 85.0 85.0 85.5 86.0 86.5 86.5
# [16] 87.0 87.5 88.0 88.0 88.0 88.5 88.5 89.0 89.0 89.0 89.0 89.5 89.5 89.5 89.5
# [31] 90.5 90.5 90.5 91.0 91.0 91.5 91.5 92.0 92.0 93.0 94.0 95.5 96.5
#  [1] 0.02325581 0.04651163 0.06976744 0.09302326 0.11627907 0.13953488
#  [7] 0.16279070 0.18604651 0.20930233 0.23255814 0.25581395 0.27906977
# [13] 0.30232558 0.32558140 0.34883721 0.37209302 0.39534884 0.41860465
# [19] 0.44186047 0.46511628 0.48837209 0.51162791 0.53488372 0.55813953
# [25] 0.58139535 0.60465116 0.62790698 0.65116279 0.67441860 0.69767442
# [31] 0.72093023 0.74418605 0.76744186 0.79069767 0.81395349 0.83720930
# [37] 0.86046512 0.88372093 0.90697674 0.93023256 0.95348837 0.97674419
# [43] 1.00000000
# Plot with title "Density estimation: contour plot"

# %%
#三维等高线图
persp(z,main = "Density estimation:perspective plot")
# Out:
# Plot with title "Density estimation:perspective plot"

# %%
library(MASS)
data(Animals)
Animals
# Out:
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:DAAG':
#
#     hills
#                  body      brain
# Mountain beaver      1.350    8.1
# Cow                465.000  423.0
# Grey wolf           36.330  119.5
# Goat                27.660  115.0
# Guinea pig           1.040    5.5
# Dipliodocus      11700.000   50.0
# Asian elephant    2547.000 4603.0
# Donkey             187.100  419.0
# Horse              521.000  655.0
# Potar monkey        10.000  115.0
# Cat                  3.300   25.6
# Giraffe            529.000  680.0
# Gorilla            207.000  406.0
# Human               62.000 1320.0
# African elephant  6654.000 5712.0
# Triceratops       9400.000   70.0
# Rhesus monkey        6.800  179.0
# Kangaroo            35.000   56.0
# Golden hamster       0.120    1.0
# Mouse                0.023    0.4
# Rabbit               2.500   12.1
# Sheep               55.500  175.0
# Jaguar             100.000  157.0
# Chimpanzee          52.160  440.0
# Rat                  0.280    1.9
# Brachiosaurus    87000.000  154.5
# Mole                 0.122    3.0
# Pig                192.000  180.0

# %%
par(mfrow = c(1,2))
plot(brain~body,data = Animals)
plot(log(brain)~log(body),data=Animals)
# Out:
# plot without title

# %% [markdown]
# #### 多组数据的图形描述

# %%
n<-10
d<-data.frame(y1 = abs(rnorm(n)),
              y2 = abs(rnorm(n)),
              y3 = abs(rnorm(n)),
              y4 = abs(rnorm(n)),
              y5 = abs(rnorm(n)))

# %%
#plot pairs
#plot(d)
pairs(d)
# Out:
# plot without title

# %%
#矩阵图
matplot(d, type = 'l', ylab = "", main = "Matplot")
# Out:
# Plot with title "Matplot"

# %%
#箱体图
boxplot(d)
# Out:
# plot without title

# %% [markdown]
# #### 多组数据的描述性统计

# %%
summary(state.x77)
# Out:
#    Population        Income       Illiteracy       Life Exp
#  Min.   :  365   Min.   :3098   Min.   :0.500   Min.   :67.96
#  1st Qu.: 1080   1st Qu.:3993   1st Qu.:0.625   1st Qu.:70.12
#  Median : 2838   Median :4519   Median :0.950   Median :70.67
#  Mean   : 4246   Mean   :4436   Mean   :1.170   Mean   :70.88
#  3rd Qu.: 4968   3rd Qu.:4814   3rd Qu.:1.575   3rd Qu.:71.89
#  Max.   :21198   Max.   :6315   Max.   :2.800   Max.   :73.60
#      Murder          HS Grad          Frost             Area
#  Min.   : 1.400   Min.   :37.80   Min.   :  0.00   Min.   :  1049
#  1st Qu.: 4.350   1st Qu.:48.05   1st Qu.: 66.25   1st Qu.: 36985
#  Median : 6.850   Median :53.25   Median :114.50   Median : 54277
#  Mean   : 7.378   Mean   :53.11   Mean   :104.46   Mean   : 70736
#  3rd Qu.:10.675   3rd Qu.:59.15   3rd Qu.:139.75   3rd Qu.: 81163
#  Max.   :15.100   Max.   :67.30   Max.   :188.00   Max.   :566432

# %%
aggregate(state.x77,by = list(Region = state.region),mean)
# Out:
#   Region        Population Income   Illiteracy Life Exp Murder    HS Grad
# 1 Northeast     5495.111   4570.222 1.000000   71.26444  4.722222 53.96667
# 2 South         4208.125   4011.938 1.737500   69.70625 10.581250 44.34375
# 3 North Central 4803.000   4611.083 0.700000   71.76667  5.275000 54.51667
# 4 West          2915.308   4702.615 1.023077   71.23462  7.215385 62.00000
#   Frost    Area
# 1 132.7778  18141.00
# 2  64.6250  54605.12
# 3 138.8333  62652.00
# 4 102.1538 134463.00

# %%
aggregate(state.x77,list(Region=state.region,Cold = state.x77[,"Frost"]>130),mean)
# Out:
#   Region        Cold  Population Income   Illiteracy Life Exp Murder
# 1 Northeast     FALSE 8802.8000  4780.400 1.1800000  71.12800  5.580000
# 2 South         FALSE 4208.1250  4011.938 1.7375000  69.70625 10.581250
# 3 North Central FALSE 7233.8333  4633.333 0.7833333  70.95667  8.283333
# 4 West          FALSE 4582.5714  4550.143 1.2571429  71.70000  6.828571
# 5 Northeast      TRUE 1360.5000  4307.500 0.7750000  71.43500  3.650000
# 6 North Central  TRUE 2372.1667  4588.833 0.6166667  72.57667  2.266667
# 7 West           TRUE  970.1667  4880.500 0.7500000  70.69167  7.666667
#   HS Grad  Frost    Area
# 1 52.06000 110.6000  21838.60
# 2 44.34375  64.6250  54605.12
# 3 53.36667 120.0000  56736.50
# 4 60.11429  51.0000  91863.71
# 5 56.35000 160.5000  13519.00
# 6 55.66667 157.6667  68567.50
# 7 64.20000 161.8333 184162.17

# %%
#标准差与协方差矩阵的计算 ??
options(digits = 4)
sd(state.x77)
# Out:
# [1] 37802

# %%
aggregate(state.x77,list(Region = state.region),sd)
# Out:
#   Region        Population Income Illiteracy Life Exp Murder HS Grad Frost
# 1 Northeast     6080       559    0.278      0.744    2.67   3.93    30.9
# 2 South         2780       605    0.552      1.022    2.63   5.74    31.3
# 3 North Central 3703       283    0.141      1.037    3.57   3.62    23.9
# 4 West          5579       664    0.608      1.352    2.68   3.50    68.9
#   Area
# 1  18076
# 2  57965
# 3  14967
# 4 134982

# %%
var(state.x77)
# Out:
#            Population Income     Illiteracy Life Exp   Murder    HS Grad
# Population 19931683.8   571229.8  292.8680  -4.078e+02  5663.524  -3551.510
# Income       571229.8   377573.3 -163.7020   2.807e+02  -521.894   3076.769
# Illiteracy      292.9     -163.7    0.3715  -4.815e-01     1.582     -3.235
# Life Exp       -407.8      280.7   -0.4815   1.802e+00    -3.869      6.313
# Murder         5663.5     -521.9    1.5818  -3.869e+00    13.627    -14.550
# HS Grad       -3551.5     3076.8   -3.2355   6.313e+00   -14.550     65.238
# Frost        -77082.0     7227.6  -21.2900   1.829e+01  -103.406    153.992
# Area        8587916.9 19049013.8 4018.3371  -1.229e+04 71940.430 229873.193
#            Frost     Area
# Population -77081.97    8587917
# Income       7227.60   19049014
# Illiteracy    -21.29       4018
# Life Exp       18.29     -12294
# Murder       -103.41      71940
# HS Grad       153.99     229873
# Frost        2702.01     262704
# Area       262703.89 7280748061

# %%
aggregate(state.x77,list(Region = state.region),var)
# Out:
#   Region        Population Income Illiteracy Life Exp Murder HS Grad Frost
# 1 Northeast     36961112   312567 0.0775     0.5534    7.132 15.43    954.4
# 2 South          7725666   366570 0.3052     1.0449    6.904 32.97    980.1
# 3 North Central 13710932    80136 0.0200     1.0748   12.740 13.13    570.9
# 4 West          31120856   440764 0.3703     1.8278    7.160 12.25   4744.0
#   Area
# 1 3.267e+08
# 2 3.360e+09
# 3 2.240e+08
# 4 1.822e+10

# %%
#相关系数的计算
x<-c(44.4, 45.9, 46.0, 46.5, 46.7, 47, 48.7, 49.2, 60.1)
y<-c(2.6, 10.1, 11.5, 30.0, 32.6, 50.0, 55.2, 85.8, 86.8)
cor(x,y)
cor(x,y,method = "spearman")
cor(x,y,method = "kendall")
plot(x,y)
# Out:
# [1] 0.7686
# [1] 1
# [1] 1
# plot without title

# %%
#条件散点图
data(cuckoos)

# %%
cuckoos
# Out:
#     length breadth species      id
# 1   21.7   16.1    meadow.pipit 21
# 2   22.6   17.0    meadow.pipit 22
# 3   20.9   16.2    meadow.pipit 23
# 4   21.6   16.2    meadow.pipit 24
# 5   22.2   16.9    meadow.pipit 25
# 6   22.5   16.9    meadow.pipit 26
# 7   22.2   17.3    meadow.pipit 27
# 8   24.3   16.8    meadow.pipit 28
# 9   22.3   16.8    meadow.pipit 29
# 10  22.6   17.0    meadow.pipit 30
# 11  20.1   16.5    meadow.pipit 31
# 12  22.0   16.9    meadow.pipit 32
# 13  22.8   16.5    meadow.pipit 33
# 14  22.0   17.0    meadow.pipit 34
# 15  22.4   17.0    meadow.pipit 35
# 16  22.3   16.3    meadow.pipit 36
# 17  20.6   16.2    meadow.pipit 37
# 18  22.1   16.8    meadow.pipit 38
# 19  21.9   17.0    meadow.pipit 39
# 20  23.0   16.9    meadow.pipit 40
# 21  22.0   17.0    meadow.pipit 41
# 22  22.0   17.0    meadow.pipit 42
# 23  22.1   17.3    meadow.pipit 43
# 24  22.0   16.8    meadow.pipit 44
# 25  19.6   15.8    meadow.pipit 45
# 26  22.8   17.1    meadow.pipit 46
# 27  22.0   16.9    meadow.pipit 47
# 28  23.4   16.4    meadow.pipit 48
# 29  23.8   16.4    meadow.pipit 49
# 30  23.3   16.8    meadow.pipit 50
# ... ...    ...     ...          ...
# 91  23.0   16.3    pied.wagtail 198
# 92  23.4   16.7    pied.wagtail 199
# 93  24.0   17.0    pied.wagtail 200
# 94  23.3   16.3    pied.wagtail 201
# 95  23.1   16.7    pied.wagtail 202
# 96  22.4   16.5    pied.wagtail 203
# 97  21.8   16.0    pied.wagtail 204
# 98  21.8   16.0    pied.wagtail 205
# 99  24.9   16.8    pied.wagtail 206
# 100 24.0   15.8    pied.wagtail 207
# 101 22.1   16.2    pied.wagtail 208
# 102 21.0   17.1    pied.wagtail 209
# 103 22.6   16.0    pied.wagtail 210
# 104 21.9   16.9    pied.wagtail 211
# 105 24.0   17.2    pied.wagtail 212
# 106 19.8   15.0    wren         224
# 107 22.1   16.0    wren         225
# 108 21.5   16.2    wren         226
# 109 20.9   15.7    wren         227
# 110 22.0   16.2    wren         228
# 111 21.0   15.5    wren         229
# 112 22.3   16.0    wren         230
# 113 21.0   15.9    wren         231
# 114 20.3   15.5    wren         232
# 115 20.9   15.9    wren         233
# 116 22.0   16.0    wren         234
# 117 20.0   15.7    wren         235
# 118 20.8   15.9    wren         236
# 119 21.2   16.0    wren         237
# 120 21.0   16.0    wren         238

# %%
coplot(cuckoos$length ~ cuckoos$breadth | cuckoos$species)
# Out:
# plot without title

# %%
attach(cuckoos)

# %%
length.mp <- length[species=="meadow.pipit"]
length.tp <- length[species=="tree.pipit"]
length.hs <- length[species=="hedge.sparrow"]
length.r <- length[species=="robin"]
length.pw <- length[species=="pied.wagtail"]
length.w <- length[species=="wren"]
par(mfrow=c(3,2))
hist(length.mp,breaks=6,probability=T,
xlim=c(19,25),ylim=c(0,1),main="",col=6)
hist(length.tp,breaks=6,probability=T,
     xlim=c(19,25),ylim=c(0,1),main="",col=6)
hist(length.hs,breaks=6,probability=T,
xlim=c(19,25),ylim=c(0,1),main="",col=6)
hist(length.r,breaks=6,probability=T,
xlim=c(19,25),ylim=c(0,1),main="",col=6)
hist(length.pw,breaks=6,probability=T,
xlim=c(19,25),ylim=c(0,1),main="",col=6)
hist(length.w,breaks=6,probability=T,
xlim=c(19,25),ylim=c(0,1),main="",col=6)
par(mfrow=c(1,1))
# Out:
# Plot with title ""

# %%
# 定义直方组图函数hists() 的定义
hists <- function (x, y, ...) {
    y <- factor(y)
    n <- length(levels(y))
    op <- par( mfcol=c(n,1), mar=c(2,4,1,1) )
    b <- hist(x, ..., plot=F)$breaks
    for (l in levels(y)){
    hist(x[y==l], breaks=b, probability=T, ylim=c(0,1.0),
    main="", ylab=l, col='lightblue', xlab="", ...)
    points(density(x[y==l]), type='l', lwd=3, col='red')
    }
    par(op)
}

# %%
hists(cuckoos$length,cuckoos$species)
# Out:
# Plot with title ""

# %%
library(lattice)

# %%
histogram(~length|species,data = cuckoos)
# Out:
# plot without title

# %%
boxplot(length~species,data=cuckoos,xlab = "length of egg",horizontal = TRUE)
# Out:
# plot without title

# %%
#条形图
stripchart(cuckoos$length~cuckoos$species,method = "jitter")
# Out:
# plot without title

# %%
#密度曲线图
densityplot(~length|species,data = cuckoos)
# Out:
# plot without title

# %% [markdown]
# ### 分类数据的描述性统计分析

# %%
#构建数据
Eye.Hair <- matrix(c(68,20,15,5, 119,84,54,29,
26,17,14,14, 7,94,10,16), nrow=4,byrow=T)
colnames(Eye.Hair) <- c("Brown", "Blue", "Hazel", "Green")
rownames(Eye.Hair) <- c("Black","Brown","Red", "Blond")
Eye.Hair
# Out:
#       Brown Blue Hazel Green
# Black  68   20   15     5
# Brown 119   84   54    29
# Red    26   17   14    14
# Blond   7   94   10    16

# %%
library(ISwR)
data(juul)
# Out:
# Attaching package: 'ISwR'
#
#
# The following object is masked from 'package:DAAG':
#
#     lung

# %%
juul
# Out:
#      age   menarche sex igf1 tanner testvol
# 1      NA  NA       NA   90  NA     NA
# 2      NA  NA       NA   88  NA     NA
# 3      NA  NA       NA  164  NA     NA
# 4      NA  NA       NA  166  NA     NA
# 5      NA  NA       NA  131  NA     NA
# 6    0.17  NA        1  101   1     NA
# 7    0.17  NA        1   97   1     NA
# 8    0.17  NA        1  106   1     NA
# 9    0.17  NA        1  111   1     NA
# 10   0.17  NA        1   79   1     NA
# 11   0.17  NA        1   43   1     NA
# 12   0.17  NA        1   64   1     NA
# 13   0.25  NA        1   90   1     NA
# 14   0.25  NA        1  141   1     NA
# 15   0.42  NA        1   42   1     NA
# 16   0.50  NA        1   43   1     NA
# 17   0.67  NA        1  132   1     NA
# 18   0.75  NA        1   43   1     NA
# 19   0.75  NA        1   36   1     NA
# 20   1.00  NA        1   86   1     NA
# 21   1.16  NA        1   44   1     NA
# 22   1.50  NA        1   68   1     NA
# 23   1.50  NA        1   89   1     NA
# 24   1.58  NA        1  101   1     NA
# 25   1.67  NA        1  115   1     NA
# 26   1.67  NA        1   53   1     NA
# 27   1.75  NA        1   94   1     NA
# 28   1.83  NA        1   95   1     NA
# 29   1.92  NA        1   76   1     NA
# 30   2.00  NA        1   79   1     NA
# ...  ...   ...      ... ...  ...    ...
# 1310 40.08 2        2   200  NA     NA
# 1311 40.91 2        2   220  NA     NA
# 1312 41.00 2        2   233  NA     NA
# 1313 41.43 2        2   206  NA     NA
# 1314 41.91 2        2   331   5     NA
# 1315 42.00 2        2   169  NA     NA
# 1316 42.69 2        2   130  NA     NA
# 1317 43.10 2        2   262  NA     NA
# 1318 43.33 2        2   100   5     NA
# 1319 43.80 2        2   249  NA     NA
# 1320 44.62 2        2   170   5     NA
# 1321 45.22 2        2   156  NA     NA
# 1322 45.28 2        2   251  NA     NA
# 1323 45.41 2        2   220  NA     NA
# 1324 47.00 2        2   174  NA     NA
# 1325 47.37 2        2   144   5     NA
# 1326 48.01 2        2   154   5     NA
# 1327 48.34 2        2    NA  NA     NA
# 1328 49.46 2        2   140  NA     NA
# 1329 51.07 2        2   187   5     NA
# 1330 52.00 2        2   140  NA     NA
# 1331 53.18 2        2   252  NA     NA
# 1332 54.00 2        2   124  NA     NA
# 1333 54.00 2        2   187  NA     NA
# 1334 58.95 2        2   218   5     NA
# 1335 60.99 2        2   226   5     NA
# 1336 62.73 2        2    NA  NA     NA
# 1337 65.00 2        2   106  NA     NA
# 1338 67.88 2        2   217  NA     NA
# 1339 75.12 2        2   135  NA     NA

# %%
table(juul$sex)
table(juul$sex,juul$menarche)
table(juul$menarche,juul$tanner)
# Out:
#   1   2
# 621 713
#
#       1   2
#   1   0   0
#   2 369 335
#
#       1   2   3   4   5
#   1 221  43  32  14   2
#   2   1   1   5  26 202

# %%
#边际列表
margin.table(Eye.Hair,1)
# Out:
# Black Brown   Red Blond
#   108   286    71   127

# %%
#边际列表
margin.table(Eye.Hair,2)
# Out:
# Brown  Blue Hazel Green
#   220   215    93    64

# %%
#频率列联表
prop.table(Eye.Hair,1)
# Out:
#       Brown   Blue   Hazel   Green
# Black 0.62963 0.1852 0.13889 0.0463
# Brown 0.41608 0.2937 0.18881 0.1014
# Red   0.36620 0.2394 0.19718 0.1972
# Blond 0.05512 0.7402 0.07874 0.1260

# %%
#频率列联表
prop.table(Eye.Hair,1)*100
# Out:
#       Brown  Blue  Hazel  Green
# Black 62.963 18.52 13.889  4.63
# Brown 41.608 29.37 18.881 10.14
# Red   36.620 23.94 19.718 19.72
# Blond  5.512 74.02  7.874 12.60

# %%
prop.table(Eye.Hair,1)*100
# Out:
#       Brown  Blue  Hazel  Green
# Black 62.963 18.52 13.889  4.63
# Brown 41.608 29.37 18.881 10.14
# Red   36.620 23.94 19.718 19.72
# Blond  5.512 74.02  7.874 12.60

# %%
Eye.Hair/sum(Eye.Hair)
# Out:
#       Brown   Blue    Hazel   Green
# Black 0.11486 0.03378 0.02534 0.008446
# Brown 0.20101 0.14189 0.09122 0.048986
# Red   0.04392 0.02872 0.02365 0.023649
# Blond 0.01182 0.15878 0.01689 0.027027

# %%
#列联表的图形描述
data(HairEyeColor)
a <- as.table(apply(HairEyeColor,c(1,2),sum))
barplot(a, legend.text = attr(a, "dimnames")$Hair)
# Out:
# plot without title

# %%
#条形图
barplot(a,beside = TRUE, legend.text = attr(a, "dimnames")$Hair)
# Out:
# plot without title

# %%
#点图
dotchart(Eye.Hair)
# Out:
# plot without title
